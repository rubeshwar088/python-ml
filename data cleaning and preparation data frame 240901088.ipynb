# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -2.025069 -0.796432  1.045036
# b       NaN       NaN       NaN
# c -0.467326  0.603915 -0.407642
# d  1.180514  0.120342  0.581174
# e       NaN       NaN       NaN
# f  0.373833 -1.204942 -0.773593
#
#
# Dropped DataFrame
#          one       two     three
# a -2.025069 -0.796432  1.045036
# c -0.467326  0.603915 -0.407642
# d  1.180514  0.120342  0.581174
# f  0.373833 -1.204942 -0.773593

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.859670  0.504470 -0.027409
# b       NaN       NaN       NaN
# c -1.630691  0.037098  0.808553
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  0.859670  0.504470 -0.027409
# b  0.000000  0.000000  0.000000
# c -1.630691  0.037098  0.808553

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  0.732132 -0.953887 -1.470277
# b       NaN       NaN       NaN
# c  1.275451 -0.315485 -0.147397
# d -0.467209 -0.701669  0.116311
# e       NaN       NaN       NaN
# f -0.290056 -0.993477  1.209375
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.405894 -0.249173 -0.827420
# b       NaN       NaN       NaN
# c -0.572175 -1.113119 -1.235654
# d -1.006796 -0.982167 -0.282789
# e       NaN       NaN       NaN
# f -0.659646 -0.409144 -2.307976
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  0.405894 -0.249173 -0.827420
# b -0.572175 -1.113119 -1.235654
# c -0.572175 -1.113119 -1.235654
# d -1.006796 -0.982167 -0.282789
# e -0.659646 -0.409144 -2.307976
# f -0.659646 -0.409144 -2.307976
